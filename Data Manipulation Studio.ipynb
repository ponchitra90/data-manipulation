# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit our California farmers looking for advice on growing pumpkins and the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

baltimore = pd.read_csv("dataset/baltimore_9-24-2016_9-30-2017.csv")
boston = pd.read_csv("dataset/boston_9-24-2016_9-30-2017.csv")
newyork = pd.read_csv("dataset/new-york_9-24-2016_9-30-2017.csv")
philadelphia = pd.read_csv("dataset/philadelphia_9-24-2016_9-30-2017.csv")

baltimore.shape
# Out:
# (153, 25)

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data to related to San Francisco. Pull up your notebook from the last lesson and use your cleaning skills to clean the dataframes as necessary.

# %%
# Clean your data here!

baltimore.head()
for col in baltimore.columns:
    pct_missing = np.mean(baltimore[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 1%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 3%
# Origin District - 100%
# Item Size - 16%
# Color - 80%
# Environment - 100%
# Unit of Sale - 84%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
baltimore = baltimore.drop(["Type","Sub Variety","Grade","Origin District","Color","Environment","Unit of Sale","Quality","Condition","Appearance","Storage","Crop","Trans Mode"], axis=1)
baltimore
# Out:
#     Commodity Name  City Name             Package      Variety        Date  \
# 0         PUMPKINS  BALTIMORE        24 inch bins          NaN  04/29/2017
# 1         PUMPKINS  BALTIMORE        24 inch bins          NaN  05/06/2017
# 2         PUMPKINS  BALTIMORE        24 inch bins  HOWDEN TYPE  09/24/2016
# 3         PUMPKINS  BALTIMORE        24 inch bins  HOWDEN TYPE  09/24/2016
# 4         PUMPKINS  BALTIMORE        24 inch bins  HOWDEN TYPE  11/05/2016
# ..             ...        ...                 ...          ...         ...
# 148       PUMPKINS  BALTIMORE  1/2 bushel cartons    MINIATURE  09/30/2017
# 149       PUMPKINS  BALTIMORE  1/2 bushel cartons    MINIATURE  09/30/2017
# 150       PUMPKINS  BALTIMORE  1/2 bushel cartons    MINIATURE  09/24/2016
# 151       PUMPKINS  BALTIMORE  1/2 bushel cartons    MINIATURE  10/01/2016
# 152       PUMPKINS  BALTIMORE  1/2 bushel cartons    MINIATURE  10/08/2016
#
#      Low Price  High Price  Mostly Low  Mostly High        Origin Item Size  \
# 0          270       280.0         270        280.0           NaN       lge
# 1          270       280.0         270        280.0           NaN       lge
# 2          160       160.0         160        160.0      DELAWARE       med
# 3          160       160.0         160        160.0      VIRGINIA       med
# 4           90       100.0          90        100.0      MARYLAND       lge
# ..         ...         ...         ...          ...           ...       ...
# 148         18        18.0          18         18.0      MARYLAND       NaN
# 149         18        18.0          18         18.0  PENNSYLVANIA       NaN
# 150         15        15.0          15         15.0      MARYLAND       sml
# 151         15        15.0          15         15.0      MARYLAND       sml
# 152         15        15.0          15         15.0      MARYLAND       sml
#
#     Repack
# 0        E
# 1        E
# 2        N
# 3        N
# 4        N
# ..     ...
# 148      N
# 149      N
# 150      N
# 151      N
# 152      N
#
# [153 rows x 12 columns]

# %%
boston.head()
for col in boston.columns:
    pct_missing = np.mean(boston[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 92%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 81%
# Item Size - 1%
# Color - 14%
# Environment - 100%
# Unit of Sale - 87%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
boston = boston.drop(["Type","Sub Variety","Grade","Origin District","Environment","Unit of Sale","Quality","Condition","Appearance","Storage","Crop","Trans Mode"], axis=1)
boston
# Out:
#     Commodity Name City Name             Package      Variety        Date  \
# 0         PUMPKINS    BOSTON        36 inch bins  HOWDEN TYPE  09/24/2016
# 1         PUMPKINS    BOSTON        36 inch bins  HOWDEN TYPE  09/24/2016
# 2         PUMPKINS    BOSTON        36 inch bins  HOWDEN TYPE  09/24/2016
# 3         PUMPKINS    BOSTON        36 inch bins  HOWDEN TYPE  09/24/2016
# 4         PUMPKINS    BOSTON        36 inch bins  HOWDEN TYPE  09/24/2016
# ..             ...       ...                 ...          ...         ...
# 347       PUMPKINS    BOSTON  1/2 bushel cartons    MINIATURE  10/22/2016
# 348       PUMPKINS    BOSTON  1/2 bushel cartons    MINIATURE  10/29/2016
# 349       PUMPKINS    BOSTON  1/2 bushel cartons    MINIATURE  10/29/2016
# 350       PUMPKINS    BOSTON  1/2 bushel cartons    MINIATURE  11/05/2016
# 351       PUMPKINS    BOSTON  1/2 bushel cartons    MINIATURE  11/05/2016
#
#      Low Price  High Price  Mostly Low  Mostly High         Origin Item Size  \
# 0          160         200         165          165         CANADA     exjbo
# 1          160         200         165          165         CANADA       jbo
# 2          160         200         165          165         CANADA      xlge
# 3          160         200         165          165         CANADA      xlge
# 4          160         180         165          165         CANADA       lge
# ..         ...         ...         ...          ...            ...       ...
# 347         15          18          15           15  MASSACHUSETTS       sml
# 348         15          18          15           15  MASSACHUSETTS       sml
# 349         15          18          15           15  MASSACHUSETTS       sml
# 350         15          18          15           15  MASSACHUSETTS       sml
# 351         15          18          15           15  MASSACHUSETTS       sml
#
#       Color Repack
# 0    ORANGE      N
# 1    ORANGE      N
# 2    ORANGE      N
# 3    ORANGE      N
# 4    ORANGE      N
# ..      ...    ...
# 347  ORANGE      N
# 348   WHITE      N
# 349  ORANGE      N
# 350   WHITE      N
# 351  ORANGE      N
#
# [352 rows x 13 columns]

# %%
newyork.head()
for col in newyork.columns:
    pct_missing = np.mean(newyork[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 87%
# Item Size - 7%
# Color - 81%
# Environment - 100%
# Unit of Sale - 78%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
newyork = newyork.drop(["Type","Sub Variety","Grade","Origin District","Color","Environment","Unit of Sale","Quality","Condition","Appearance","Storage","Crop","Trans Mode"], axis=1)
newyork
# Out:
#     Commodity Name City Name              Package      Variety        Date  \
# 0         PUMPKINS  NEW YORK         36 inch bins  HOWDEN TYPE  09/24/2016
# 1         PUMPKINS  NEW YORK         36 inch bins  HOWDEN TYPE  09/24/2016
# 2         PUMPKINS  NEW YORK         36 inch bins  HOWDEN TYPE  09/24/2016
# 3         PUMPKINS  NEW YORK         36 inch bins  HOWDEN TYPE  09/24/2016
# 4         PUMPKINS  NEW YORK         36 inch bins  HOWDEN TYPE  09/24/2016
# ..             ...       ...                  ...          ...         ...
# 107       PUMPKINS  NEW YORK       bushel cartons    MINIATURE  09/09/2017
# 108       PUMPKINS  NEW YORK  1 1/9 bushel crates    MINIATURE  10/08/2016
# 109       PUMPKINS  NEW YORK  1 1/9 bushel crates    MINIATURE  10/08/2016
# 110       PUMPKINS  NEW YORK  1 1/9 bushel crates    MINIATURE  10/15/2016
# 111       PUMPKINS  NEW YORK  1 1/9 bushel crates    MINIATURE  10/15/2016
#
#      Low Price  High Price  Mostly Low  Mostly High      Origin Item Size  \
# 0          150         170         150          170    MICHIGAN      xlge
# 1          150         170         150          170    MICHIGAN       lge
# 2          130         150         130          150  NEW JERSEY      xlge
# 3          130         150         130          150  NEW JERSEY       lge
# 4          120         140         120          140    NEW YORK   med-lge
# ..         ...         ...         ...          ...         ...       ...
# 107         32          32          32           32        OHIO       sml
# 108         18          18          18           18    NEW YORK       med
# 109         18          18          18           18    NEW YORK       sml
# 110         18          18          18           18    NEW YORK       med
# 111         18          18          18           18    NEW YORK       sml
#
#     Repack
# 0        N
# 1        N
# 2        N
# 3        N
# 4        N
# ..     ...
# 107      N
# 108      N
# 109      N
# 110      N
# 111      N
#
# [112 rows x 12 columns]

# %%
philadelphia.head()
for col in philadelphia.columns:
    pct_missing = np.mean(philadelphia[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 79%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 100%
# Item Size - 21%
# Color - 100%
# Environment - 100%
# Unit of Sale - 81%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%

# %%
philadelphia = philadelphia.drop(["Type","Sub Variety","Grade","Origin District","Color","Environment","Unit of Sale","Quality","Condition","Appearance","Storage","Crop","Trans Mode"], axis=1)
philadelphia
# Out:
#    Commodity Name     City Name               Package       Variety  \
# 0        PUMPKINS  PHILADELPHIA          24 inch bins   HOWDEN TYPE
# 1        PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 2        PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 3        PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 4        PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 5        PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 6        PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 7        PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 8        PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 9        PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 10       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 11       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 12       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 13       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 14       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 15       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 16       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 17       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 18       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 19       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 20       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 21       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 22       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 23       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 24       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 25       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 26       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 27       PUMPKINS  PHILADELPHIA          36 inch bins   HOWDEN TYPE
# 28       PUMPKINS  PHILADELPHIA  1 1/9 bushel cartons      PIE TYPE
# 29       PUMPKINS  PHILADELPHIA  1 1/9 bushel cartons      PIE TYPE
# 30       PUMPKINS  PHILADELPHIA  1 1/9 bushel cartons      PIE TYPE
# 31       PUMPKINS  PHILADELPHIA  1 1/9 bushel cartons      PIE TYPE
# 32       PUMPKINS  PHILADELPHIA  1 1/9 bushel cartons      PIE TYPE
# 33       PUMPKINS  PHILADELPHIA  1 1/9 bushel cartons      PIE TYPE
# 34       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 35       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 36       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 37       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 38       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 39       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 40       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 41       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 42       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 43       PUMPKINS  PHILADELPHIA          24 inch bins      PIE TYPE
# 44       PUMPKINS  PHILADELPHIA          24 inch bins  KNUCKLE HEAD
# 45       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 46       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 47       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 48       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 49       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 50       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 51       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 52       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 53       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 54       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 55       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
# 56       PUMPKINS  PHILADELPHIA    1/2 bushel cartons     MINIATURE
#
#           Date  Low Price  High Price  Mostly Low  Mostly High        Origin  \
# 0   09/16/2017        140         150         140          150  PENNSYLVANIA
# 1   09/24/2016        150         150         150          150      NEW YORK
# 2   09/24/2016        150         150         150          150      NEW YORK
# 3   09/24/2016        150         160         150          160  PENNSYLVANIA
# 4   10/01/2016        140         140         140          140    NEW JERSEY
# 5   10/01/2016        140         140         140          140  PENNSYLVANIA
# 6   10/01/2016        120         120         120          120  PENNSYLVANIA
# 7   10/08/2016        140         155         140          155    NEW JERSEY
# 8   10/08/2016        120         120         120          120    NEW JERSEY
# 9   10/15/2016        120         125         120          125  PENNSYLVANIA
# 10  10/15/2016        100         125         100          125  PENNSYLVANIA
# 11  10/22/2016        130         140         130          140    NEW JERSEY
# 12  10/22/2016        120         120         120          120  PENNSYLVANIA
# 13  10/22/2016        130         140         130          140  PENNSYLVANIA
# 14  10/22/2016        100         120         100          120  PENNSYLVANIA
# 15  10/29/2016        130         140         130          140    NEW JERSEY
# 16  10/29/2016        120         120         120          120  PENNSYLVANIA
# 17  10/29/2016        130         140         130          140  PENNSYLVANIA
# 18  10/29/2016        100         120         120          120  PENNSYLVANIA
# 19  09/16/2017        120         120         120          120  PENNSYLVANIA
# 20  09/16/2017        120         150         120          150  PENNSYLVANIA
# 21  09/23/2017        140         140         140          140      DELAWARE
# 22  09/23/2017        150         150         150          150      DELAWARE
# 23  09/23/2017        120         150         120          150      NEW YORK
# 24  09/23/2017        140         150         140          150  PENNSYLVANIA
# 25  09/23/2017        140         150         140          150  PENNSYLVANIA
# 26  09/30/2017        140         140         140          140      DELAWARE
# 27  09/30/2017        140         140         140          140      DELAWARE
# 28  10/15/2016         12          14          12           14          OHIO
# 29  10/22/2016         12          12          12           12          OHIO
# 30  10/29/2016         12          12          12           12          OHIO
# 31  08/26/2017         18          20          18           20      MICHIGAN
# 32  09/16/2017         18          18          18           18          OHIO
# 33  09/23/2017         18          22          18           22          OHIO
# 34  10/01/2016        250         250         250          250  PENNSYLVANIA
# 35  10/15/2016        140         140         140          140  PENNSYLVANIA
# 36  10/22/2016        140         150         140          150  PENNSYLVANIA
# 37  10/22/2016         75         100          75          100  PENNSYLVANIA
# 38  10/29/2016        140         150         140          150  PENNSYLVANIA
# 39  10/29/2016         75         100          75          100  PENNSYLVANIA
# 40  09/23/2017        180         180         180          180      DELAWARE
# 41  09/23/2017        140         140         140          140      DELAWARE
# 42  09/23/2017        180         180         180          180      NEW YORK
# 43  09/30/2017        140         140         140          140      DELAWARE
# 44  10/08/2016        210         210         210          210    NEW JERSEY
# 45  09/24/2016         17          18          17           18          OHIO
# 46  10/01/2016         18          18          18           18    NEW JERSEY
# 47  10/01/2016         17          18          17           18          OHIO
# 48  10/08/2016         15          15          15           15          OHIO
# 49  10/15/2016         15          18          15           18          OHIO
# 50  10/22/2016         16          18          16           18          OHIO
# 51  10/29/2016         16          18          16           18          OHIO
# 52  11/05/2016         16          18          16           18          OHIO
# 53  08/26/2017         18          20          18           20      MICHIGAN
# 54  09/16/2017         16          16          16           16          OHIO
# 55  09/23/2017         15          16          15           16          OHIO
# 56  09/30/2017         15          18          15           18          OHIO
#
#    Item Size Repack
# 0        lge      N
# 1    med-lge      N
# 2        med      N
# 3        lge      N
# 4    med-lge      N
# 5    med-lge      N
# 6        med      N
# 7        med      N
# 8        sml      N
# 9        lge      N
# 10       med      N
# 11   med-lge      N
# 12       lge      N
# 13   med-lge      N
# 14       med      N
# 15   med-lge      N
# 16       lge      N
# 17   med-lge      N
# 18       med      N
# 19       lge      N
# 20       med      N
# 21       lge      N
# 22       med      N
# 23       lge      N
# 24      xlge      N
# 25       lge      N
# 26       lge      N
# 27       med      N
# 28       med      N
# 29       med      N
# 30       med      N
# 31       med      N
# 32       med      N
# 33       med      N
# 34       med      N
# 35       med      N
# 36       med      N
# 37       sml      N
# 38       med      N
# 39       sml      N
# 40       med      N
# 41       sml      N
# 42       med      N
# 43       sml      N
# 44       med      N
# 45       NaN      N
# 46       NaN      N
# 47       NaN      N
# 48       NaN      N
# 49       NaN      N
# 50       NaN      N
# 51       NaN      N
# 52       NaN      N
# 53       NaN      N
# 54       NaN      N
# 55       NaN      N
# 56       NaN      N

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!
data = pd.concat([baltimore,boston,newyork,philadelphia])
data
# Out:
#    Commodity Name     City Name             Package      Variety        Date  \
# 0        PUMPKINS     BALTIMORE        24 inch bins          NaN  04/29/2017
# 1        PUMPKINS     BALTIMORE        24 inch bins          NaN  05/06/2017
# 2        PUMPKINS     BALTIMORE        24 inch bins  HOWDEN TYPE  09/24/2016
# 3        PUMPKINS     BALTIMORE        24 inch bins  HOWDEN TYPE  09/24/2016
# 4        PUMPKINS     BALTIMORE        24 inch bins  HOWDEN TYPE  11/05/2016
# ..            ...           ...                 ...          ...         ...
# 52       PUMPKINS  PHILADELPHIA  1/2 bushel cartons    MINIATURE  11/05/2016
# 53       PUMPKINS  PHILADELPHIA  1/2 bushel cartons    MINIATURE  08/26/2017
# 54       PUMPKINS  PHILADELPHIA  1/2 bushel cartons    MINIATURE  09/16/2017
# 55       PUMPKINS  PHILADELPHIA  1/2 bushel cartons    MINIATURE  09/23/2017
# 56       PUMPKINS  PHILADELPHIA  1/2 bushel cartons    MINIATURE  09/30/2017
#
#     Low Price  High Price  Mostly Low  Mostly High    Origin Item Size Repack  \
# 0         270       280.0         270        280.0       NaN       lge      E
# 1         270       280.0         270        280.0       NaN       lge      E
# 2         160       160.0         160        160.0  DELAWARE       med      N
# 3         160       160.0         160        160.0  VIRGINIA       med      N
# 4          90       100.0          90        100.0  MARYLAND       lge      N
# ..        ...         ...         ...          ...       ...       ...    ...
# 52         16        18.0          16         18.0      OHIO       NaN      N
# 53         18        20.0          18         20.0  MICHIGAN       NaN      N
# 54         16        16.0          16         16.0      OHIO       NaN      N
# 55         15        16.0          15         16.0      OHIO       NaN      N
# 56         15        18.0          15         18.0      OHIO       NaN      N
#
#    Color
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 52   NaN
# 53   NaN
# 54   NaN
# 55   NaN
# 56   NaN
#
# [674 rows x 13 columns]

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of unit of sale in the Northeast region? In the last lesson, we learned that a unit of sale could be something like a bin or individually.
# 2. What is the average number of pumpkins for each variety that came into terminal markets for the year by region? Pumpkin varieties include Howden and Fairytale pumpkins.

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
mean_low_high_prices = {"Low Price":"mean","High Price":"mean"}
data.agg(mean_low_high_prices)
# Out:
# Low Price     134.183976
# High Price    150.671365
# dtype: float64

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety.
pumpkin_variety = data.groupby(["Variety"])
pumpkin_variety.first()
# Out:
#                          Commodity Name  City Name               Package  \
# Variety
# BIG MACK TYPE                  PUMPKINS  BALTIMORE          24 inch bins
# BLUE TYPE                      PUMPKINS     BOSTON          24 inch bins
# CINDERELLA                     PUMPKINS  BALTIMORE          24 inch bins
# FAIRYTALE                      PUMPKINS  BALTIMORE          24 inch bins
# HOWDEN TYPE                    PUMPKINS  BALTIMORE          24 inch bins
# HOWDEN WHITE TYPE              PUMPKINS  BALTIMORE          24 inch bins
# KNUCKLE HEAD                   PUMPKINS     BOSTON          24 inch bins
# MINIATURE                      PUMPKINS  BALTIMORE    1/2 bushel cartons
# MIXED HEIRLOOM VARIETIES       PUMPKINS  BALTIMORE          24 inch bins
# PIE TYPE                       PUMPKINS  BALTIMORE  1 1/9 bushel cartons
#
#                                 Date  Low Price  High Price  Mostly Low  \
# Variety
# BIG MACK TYPE             09/24/2016         50        60.0          50
# BLUE TYPE                 09/24/2016        260       285.0         285
# CINDERELLA                06/03/2017        380       380.0         380
# FAIRYTALE                 09/24/2016        250       260.0         250
# HOWDEN TYPE               09/24/2016        160       160.0         160
# HOWDEN WHITE TYPE         09/23/2017        160       180.0         160
# KNUCKLE HEAD              09/24/2016        260       285.0         285
# MINIATURE                 09/24/2016         18        18.0          18
# MIXED HEIRLOOM VARIETIES  09/16/2017        160       240.0         160
# PIE TYPE                  09/24/2016         15        15.0          15
#
#                           Mostly High         Origin Item Size Repack   Color
# Variety
# BIG MACK TYPE                    60.0       MARYLAND       jbo      N  ORANGE
# BLUE TYPE                       285.0  MASSACHUSETTS      xlge      N  ORANGE
# CINDERELLA                      380.0         MEXICO      xlge      E  ORANGE
# FAIRYTALE                       260.0       MARYLAND      xlge      N  ORANGE
# HOWDEN TYPE                     160.0       DELAWARE       med      N  ORANGE
# HOWDEN WHITE TYPE               180.0       MARYLAND       med      N    None
# KNUCKLE HEAD                    285.0  MASSACHUSETTS      xlge      N  ORANGE
# MINIATURE                        18.0       MARYLAND       sml      N   WHITE
# MIXED HEIRLOOM VARIETIES        240.0       MARYLAND      None      N    None
# PIE TYPE                         15.0       DELAWARE       med      N  ORANGE

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
